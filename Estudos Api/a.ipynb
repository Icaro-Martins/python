# %%
import json
import requests
import pandas as pd

data = []

#url = "https://olinda.bcb.gov.br/olinda/servico/mecir_dinheiro_em_circulacao/versao/v1/odata/informacoes_diarias?$top=1000&$format=json"
url = "https://data.cityofnewyork.us/resource/rc75-m7u3.json"

source = requests.request('GET', url=url)
data = json.loads(source.text)

table = pd.DataFrame(data)

display(table)
# Out:
#             date_of_interest case_count probable_case_count  \
# 0    2020-02-29T00:00:00.000          1                   0
# 1    2020-03-01T00:00:00.000          0                   0
# 2    2020-03-02T00:00:00.000          0                   0
# 3    2020-03-03T00:00:00.000          1                   0
# 4    2020-03-04T00:00:00.000          5                   0
# ..                       ...        ...                 ...
# 995  2022-11-20T00:00:00.000       1340                 556
# 996  2022-11-21T00:00:00.000       3012                 760
# 997  2022-11-22T00:00:00.000       2701                 567
# 998  2022-11-23T00:00:00.000       2702                 797
# 999  2022-11-24T00:00:00.000       1007                 349
#
#     hospitalized_count death_count probable_death_count case_count_7day_avg  \
# 0                    1           0                    0                   0
# 1                    1           0                    0                   0
# ...

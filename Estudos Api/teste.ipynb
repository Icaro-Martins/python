# %%
import json
import requests
import pandas as pd

response_data = []
data = []

url = "https://data.cityofnewyork.us/resource/rc75-m7u3.json"

response = requests.request('GET',url)

response_data = json.loads(response.text)
data.append(response_data)

#df = pd.DataFrame(json.loads(response.content))

display(data[0])
# Out:
# [{'date_of_interest': '2020-02-29T00:00:00.000',
#   'case_count': '1',
#   'probable_case_count': '0',
#   'hospitalized_count': '1',
#   'death_count': '0',
#   'probable_death_count': '0',
#   'case_count_7day_avg': '0',
#   'all_case_count_7day_avg': '0',
#   'hosp_count_7day_avg': '0',
#   'death_count_7day_avg': '0',
#   'all_death_count_7day_avg': '0',
#   'bx_case_count': '0',
#   'bx_probable_case_count': '0',
#   'bx_hospitalized_count': '0',
#   'bx_death_count': '0',
#   'bx_probable_death_count': '0',
#   'bx_case_count_7day_avg': '0',
#   'bx_probable_case_count_7day_avg': '0',
#   'bx_all_case_count_7day_avg': '0',
#   'bx_hospitalized_count_7day_avg': '0',
#   'bx_death_count_7day_avg': '0',
#   'bx_all_death_count_7day_avg': '0',
#   'bk_case_count': '0',
#   'bk_probable_case_count': '0',
#   'bk_hospitalized_count': '1',
#   'bk_death_count': '0',
#   'bk_probable_death_count': '0',
#   'bk_case_count_7day_avg': '0',
#   'bk_probable_case_count_7day_avg': '0',
#   'bk_all_case_count_7day_avg': '0',
#   'bk_hospitalized_count_7day_avg': '0',
#   'bk_death_count_7day_avg': '0',
#   'bk_all_death_count_7day_avg': '0',
#   'mn_case_count': '1',
#   'mn_probable_case_count': '0',
#   'mn_hospitalized_count': '0',
#   'mn_death_count': '0',
#   'mn_probable_death_count': '0',
#   'mn_case_count_7day_avg': '0',
#   'mn_probable_case_count_7day_avg': '0',
#   'mn_all_case_count_7day_avg': '0',
#   'mn_hospitalized_count_7day_avg': '0',
#   'mn_death_count_7day_avg': '0',
#   'mn_all_death_count_7day_avg': '0',
#   'qn_case_count': '0',
#   'qn_probable_case_count': '0',
#   'qn_hospitalized_count': '0',
#   'qn_death_count': '0',
#   'qn_probable_death_count': '0',
#   'qn_case_count_7day_avg': '0',
#   'qn_probable_case_count_7day_avg': '0',
#   'qn_all_case_count_7day_avg': '0',
#   'qn_hospitalized_count_7day_avg': '0',
#   'qn_death_count_7day_avg': '0',
#   'qn_all_death_count_7day_avg': '0',
#   'si_case_count': '0',
#   'si_probable_case_count': '0',
#   'si_hospitalized_count': '0',
#   'si_death_count': '0',
#   'si_probable_death_count': '0',
#   'si_probable_case_count_7day_avg': '0',
#   'si_case_count_7day_avg': '0',
#   'si_all_case_count_7day_avg': '0',
#   'si_hospitalized_count_7day_avg': '0',
#   'si_death_count_7day_avg': '0',
#   'si_all_death_count_7day_avg': '0',
#   'incomplete': '0'},
#  {'date_of_interest': '2020-03-01T00:00:00.000',
#   'case_count': '0',
#   'probable_case_count': '0',
#   'hospitalized_count': '1',
#   'death_count': '0',
#   'probable_death_count': '0',
#   'case_count_7day_avg': '0',
#   'all_case_count_7day_avg': '0',
#   'hosp_count_7day_avg': '0',
#   'death_count_7day_avg': '0',
#   'all_death_count_7day_avg': '0',
#   'bx_case_count': '0',
#   'bx_probable_case_count': '0',
#   'bx_hospitalized_count': '1',
#   'bx_death_count': '0',
#   'bx_probable_death_count': '0',
#   'bx_case_count_7day_avg': '0',
#   'bx_probable_case_count_7day_avg': '0',
#   'bx_all_case_count_7day_avg': '0',
#   'bx_hospitalized_count_7day_avg': '0',
#   'bx_death_count_7day_avg': '0',
#   'bx_all_death_count_7day_avg': '0',
#   'bk_case_count': '0',
#   'bk_probable_case_count': '0',
#   'bk_hospitalized_count': '0',
#   'bk_death_count': '0',
#   'bk_probable_death_count': '0',
#   'bk_case_count_7day_avg': '0',
#   'bk_probable_case_count_7day_avg': '0',
#   'bk_all_case_count_7day_avg': '0',
#   'bk_hospitalized_count_7day_avg': '0',
#   'bk_death_count_7day_avg': '0',
#   'bk_all_death_count_7day_avg': '0',
#   'mn_case_count': '0',
#   'mn_probable_case_count': '0',
#   'mn_hospitalized_count': '0',
#   'mn_death_count': '0',
#   'mn_probable_death_count': '0',
#   'mn_case_count_7day_avg': '0',
#   'mn_probable_case_count_7day_avg': '0',
#   'mn_all_case_count_7day_avg': '0',
#   'mn_hospitalized_count_7day_avg': '0',
#   'mn_death_count_7day_avg': '0',
#   'mn_all_death_count_7day_avg': '0',
#   'qn_case_count': '0',
#   'qn_probable_case_count': '0',
#   'qn_hospitalized_count': '0',
#   'qn_death_count': '0',
#   'qn_probable_death_count': '0',
#   'qn_case_count_7day_avg': '0',
#   'qn_probable_case_count_7day_avg': '0',
#   'qn_all_case_count_7day_avg': '0',
#   'qn_hospitalized_count_7day_avg': '0',
#   'qn_death_count_7day_avg': '0',
#   'qn_all_death_count_7day_avg': '0',
#   'si_case_count': '0',
#   'si_probable_case_count': '0',
#   'si_hospitalized_count': '0',
#   'si_death_count': '0',
#   'si_probable_death_count': '0',
#   'si_probable_case_count_7day_avg': '0',
#   'si_case_count_7day_avg': '0',
#   'si_all_case_count_7day_avg': '0',
#   'si_hospitalized_count_7day_avg': '0',
#   'si_death_count_7day_avg': '0',
#   'si_all_death_count_7day_avg': '0',
#   'incomplete': '0'},
#  {'date_of_interest': '2020-03-02T00:00:00.000',
#   'case_count': '0',
#   'probable_case_count': '0',
#   'hospitalized_count': '2',
#   'death_count': '0',
#   'probable_death_count': '0',
#   'case_count_7day_avg': '0',
#   'all_case_count_7day_avg': '0',
#   'hosp_count_7day_avg': '0',
#   'death_count_7day_avg': '0',
#   'all_death_count_7day_avg': '0',
#   'bx_case_count': '0',
#   'bx_probable_case_count': '0',
#   'bx_hospitalized_count': '0',
#   'bx_death_count': '0',
#   'bx_probable_death_count': '0',
#   'bx_case_count_7day_avg': '0',
#   'bx_probable_case_count_7day_avg': '0',
#   'bx_all_case_count_7day_avg': '0',
#   'bx_hospitalized_count_7day_avg': '0',
#   'bx_death_count_7day_avg': '0',
#   'bx_all_death_count_7day_avg': '0',
#   'bk_case_count': '0',
#   'bk_probable_case_count': '0',
#   'bk_hospitalized_count': '2',
#   'bk_death_count': '0',
#   'bk_probable_death_count': '0',
#   'bk_case_count_7day_avg': '0',
#   'bk_probable_case_count_7day_avg': '0',
#   'bk_all_case_count_7day_avg': '0',
#   'bk_hospitalized_count_7day_avg': '0',
#   'bk_death_count_7day_avg': '0',
#   'bk_all_death_count_7day_avg': '0',
#   'mn_case_count': '0',
#   'mn_probable_case_count': '0',
#   'mn_hospitalized_count': '0',
#   'mn_death_count': '0',
#   'mn_probable_death_count': '0',
#   'mn_case_count_7day_avg': '0',
#   'mn_probable_case_count_7day_avg': '0',
#   'mn_all_case_count_7day_avg': '0',
#   'mn_hospitalized_count_7day_avg': '0',
#   'mn_death_count_7day_avg': '0',
#   'mn_all_death_count_7day_avg': '0',
#   'qn_case_count': '0',
#   'qn_probable_case_count': '0',
#   'qn_hospitalized_count': '0',
#   'qn_death_count': '0',
#   'qn_probable_death_count': '0',
#   'qn_case_count_7day_avg': '0',
#   'qn_probable_case_count_7day_avg': '0',
#   'qn_all_case_count_7day_avg': '0',
#   'qn_hospitalized_count_7day_avg': '0',
#   'qn_death_count_7day_avg': '0',
#   'qn_all_death_count_7day_avg': '0',
#   'si_case_count': '0',
#   'si_probable_case_count': '0',
#   'si_hospitalized_count': '0',
#   'si_death_count': '0',
#   'si_probable_death_count': '0',
#   'si_probable_case_count_7day_avg': '0',
#   'si_case_count_7day_avg': '0',
#   'si_all_case_count_7day_avg': '0',
#   'si_hospitalized_count_7day_avg': '0',
#   'si_death_count_7day_avg': '0',
#   'si_all_death_count_7day_avg': '0',
#   'incomplete': '0'},
#  {'date_of_interest': '2020-03-03T00:00:00.000',
#   'case_count': '1',
#   'probable_case_count': '0',
#   'hospitalized_count': '7',
#   'death_count': '0',
#   'probable_death_count': '0',
#   'case_count_7day_avg': '0',
#   'all_case_count_7day_avg': '0',
#   'hosp_count_7day_avg': '0',
#   'death_count_7day_avg': '0',
#   'all_death_count_7day_avg': '0',
#   'bx_case_count': '0',
#   'bx_probable_case_count': '0',
#   'bx_hospitalized_count': '1',
#   'bx_death_count': '0',
#   'bx_probable_death_count': '0',
#   'bx_case_count_7day_avg': '0',
#   'bx_probable_case_count_7day_avg': '0',
#   'bx_all_case_count_7day_avg': '0',
#   'bx_hospitalized_count_7day_avg': '0',
#   'bx_death_count_7day_avg': '0',
#   'bx_all_death_count_7day_avg': '0',
#   'bk_case_count': '0',
#   'bk_probable_case_count': '0',
#   'bk_hospitalized_count': '3',
#   'bk_death_count': '0',
#   'bk_probable_death_count': '0',
#   'bk_case_count_7day_avg': '0',
#   'bk_probable_case_count_7day_avg': '0',
#   'bk_all_case_count_7day_avg': '0',
#   'bk_hospitalized_count_7day_avg': '0',
#   'bk_death_count_7day_avg': '0',
#   'bk_all_death_count_7day_avg': '0',
#   'mn_case_count': '0',
#   'mn_probable_case_count': '0',
#   'mn_hospitalized_count': '1',
#   'mn_death_count': '0',
#   'mn_probable_death_count': '0',
#   'mn_case_count_7day_avg': '0',
#   'mn_probable_case_count_7day_avg': '0',
#   'mn_all_case_count_7day_avg': '0',
#   'mn_hospitalized_count_7day_avg': '0',
#   'mn_death_count_7day_avg': '0',
#   'mn_all_death_count_7day_avg': '0',
#   'qn_case_count': '1',
#   'qn_probable_case_count': '0',
#   'qn_hospitalized_count': '2',
#   'qn_death_count': '0',
#   'qn_probable_death_count': '0',
#   'qn_case_count_7day_avg': '0',
#   'qn_probable_case_count_7day_avg': '0',
#   'qn_all_case_count_7day_avg': '0',
#   'qn_hospitalized_count_7day_avg': '0',
#   'qn_death_count_7day_avg': '0',
#   'qn_all_death_count_7day_avg': '0',
#   'si_case_count': '0',
#   'si_probable_case_count': '0',
#   'si_hospitalized_count': '0',
#   'si_death_count': '0',
#   'si_probable_death_count': '0',
#   'si_probable_case_count_7day_avg': '0',
#   'si_case_count_7day_avg': '0',
#   'si_all_case_count_7day_avg': '0',
#   'si_hospitalized_count_7day_avg': '0',
#   'si_death_count_7day_avg': '0',
#   'si_all_death_count_7day_avg': '0',
#   'incomplete': '0'},
#  {'date_of_interest': '2020-03-04T00:00:00.000',
#   'case_count': '5',
#   'probable_case_count': '0',
#   'hospitalized_count': '2',
#   'death_count': '0',
#   'probable_death_count': '0',
#   'case_count_7day_avg': '0',
#   'all_case_count_7day_avg': '0',
#   'hosp_count_7day_avg': '0',
#   'death_count_7day_avg': '0',
#   'all_death_count_7day_avg': '0',
#   'bx_case_count': '0',
#   'bx_probable_case_count': '0',
#   'bx_hospitalized_count': '0',
#   'bx_death_count': '0',
#   'bx_probable_death_count': '0',
#   'bx_case_count_7day_avg': '0',
#   'bx_probable_case_count_7day_avg': '0',
#   'bx_all_case_count_7day_avg': '0',
#   'bx_hospitalized_count_7day_avg': '0',
#   'bx_death_count_7day_avg': '0',
#   'bx_all_death_count_7day_avg': '0',
#   'bk_case_count': '1',
#   'bk_probable_case_count': '0',
#   'bk_hospitalized_count': '1',
#   'bk_death_count': '0',
#   'bk_probable_death_count': '0',
#   'bk_case_count_7day_avg': '0',
#   'bk_probable_case_count_7day_avg': '0',
#   'bk_all_case_count_7day_avg': '0',
#   'bk_hospitalized_count_7day_avg': '0',
#   'bk_death_count_7day_avg': '0',
#   'bk_all_death_count_7day_avg': '0',
#   'mn_case_count': '2',
#   'mn_probable_case_count': '0',
#   'mn_hospitalized_count': '1',
#   'mn_death_count': '0',
#   'mn_probable_death_count': '0',
#   'mn_case_count_7day_avg': '0',
#   'mn_probable_case_count_7day_avg': '0',
#   'mn_all_case_count_7day_avg': '0',
#   'mn_hospitalized_count_7day_avg': '0',
#   'mn_death_count_7day_avg': '0',
#   'mn_all_death_count_7day_avg': '0',
#   'qn_case_count': '2',
#   'qn_probable_case_count': '0',
#   'qn_hospitalized_count': '0',
#   'qn_death_count': '0',
#   'qn_probable_death_count': '0',
#   'qn_case_count_7day_avg': '0',
#   'qn_probable_case_count_7day_avg': '0',
#   'qn_all_case_count_7day_avg': '0',
#   'qn_hospitalized_count_7day_avg': '0',
#   'qn_death_count_7day_avg': '0',
#   'qn_all_death_count_7day_avg': '0',
#   'si_case_count': '0',
#   'si_probable_case_count': '0',
#   'si_hospitalized_count': '0',
#   'si_death_count': '0',
#   'si_probable_death_count': '0',
#   'si_probable_case_count_7day_avg': '0',
#   'si_case_count_7day_avg': '0',
#   'si_all_case_count_7day_avg': '0',
#   'si_hospitalized_count_7day_avg': '0',
#   'si_death_count_7day_avg': '0',
#   'si_all_death_count_7day_avg': '0',
#   'incomplete': '0'},
#  {'date_of_interest': '2020-03-05T00:00:00.000',
#   'case_count': '3',
#   'probable_case_count': '0',
#   'hospitalized_count': '14',
#   'death_count': '0',
#   'probable_death_count': '0',
#   'case_count_7day_avg': '0',
#   'all_case_count_7day_avg': '0',
#   'hosp_count_7day_avg': '0',
#   'death_count_7day_avg': '0',
#   'all_death_count_7day_avg': '0',
#   'bx_case_count': '0',
#   'bx_probable_case_count': '0',
#   'bx_hospitalized_count': '1',
#   'bx_death_count': '0',
#   'bx_probable_death_count': '0',
#   'bx_case_count_7day_avg': '0',
#   'bx_probable_case_count_7day_avg': '0',
#   'bx_all_case_count_7day_avg': '0',
#   'bx_hospitalized_count_7day_avg': '0',
#   'bx_death_count_7day_avg': '0',
#   'bx_all_death_count_7day_avg': '0',
#   'bk_case_count': '3',
#   'bk_probable_case_count': '0',
#   'bk_hospitalized_count': '3',
#   'bk_death_count': '0',
#   'bk_probable_death_count': '0',
#   'bk_case_count_7day_avg': '0',
#   'bk_probable_case_count_7day_avg': '0',
#   'bk_all_case_count_7day_avg': '0',
#   'bk_hospitalized_count_7day_avg': '0',
#   'bk_death_count_7day_avg': '0',
#   'bk_all_death_count_7day_avg': '0',
#   'mn_case_count': '0',
#   'mn_probable_case_count': '0',
#   'mn_hospitalized_count': '5',
#   'mn_death_count': '0',
#   'mn_probable_death_count': '0',
#   'mn_case_count_7day_avg': '0',
#   'mn_probable_case_count_7day_avg': '0',
#   'mn_all_case_count_7day_avg': '0',
#   'mn_hospitalized_count_7day_avg': '0',
#   'mn_death_count_7day_avg': '0',
#   'mn_all_death_count_7day_avg': '0',
#   'qn_case_count': '0',
#   'qn_probable_case_count': '0',
#   'qn_hospitalized_count': '4',
#   'qn_death_count': '0',
#   'qn_probable_death_count': '0',
#   'qn_case_count_7day_avg': '0',
#   'qn_probable_case_count_7day_avg': '0',
#   'qn_all_case_count_7day_avg': '0',
#   'qn_hospitalized_count_7day_avg': '0',
#   'qn_death_count_7day_avg': '0',
#   'qn_all_death_count_7day_avg': '0',
#   'si_case_count': '0',
#   'si_probable_case_count': '0',
#   'si_hospitalized_count': '1',
#   'si_death_count': '0',
#   'si_probable_death_count': '0',
#   'si_probable_case_count_7day_avg': '0',
#   'si_case_count_7day_avg': '0',
#   'si_all_case_count_7day_avg': '0',
#   'si_hospitalized_count_7day_avg': '0',
#   'si_death_count_7day_avg': '0',
#   'si_all_death_count_7day_avg': '0',
#   'incomplete': '0'},
#  {'date_of_interest': '2020-03-06T00:00:00.000',
#   'case_count': '8',
#   'probable_case_count': '0',
#   'hospitalized_count': '8',
#   'death_count': '0',
#   'probable_death_count': '0',
#   'case_count_7day_avg': '3',
#   'all_case_count_7day_avg': '3',
#   'hosp_count_7day_avg': '5',
#   'death_count_7day_avg': '0',
#   'all_death_count_7day_avg': '0',
#   'bx_case_count': '2',
#   'bx_probable_case_count': '0',
#   'bx_hospitalized_count': '1',
#   'bx_death_count': '0',
#   'bx_probable_death_count': '0',
#   'bx_case_count_7day_avg': '0',
#   'bx_probable_case_count_7day_avg': '0',
#   'bx_all_case_count_7day_avg': '0',
#   'bx_hospitalized_count_7day_avg': '1',
#   'bx_death_count_7day_avg': '0',
#   'bx_all_death_count_7day_avg': '0',
#   'bk_case_count': '1',
#   'bk_probable_case_count': '0',
#   'bk_hospitalized_count': '1',
#   'bk_death_count': '0',
#   'bk_probable_death_count': '0',
#   'bk_case_count_7day_avg': '1',
#   'bk_probable_case_count_7day_avg': '0',
#   'bk_all_case_count_7day_avg': '1',
#   'bk_hospitalized_count_7day_avg': '2',
#   'bk_death_count_7day_avg': '0',
#   'bk_all_death_count_7day_avg': '0',
#   'mn_case_count': '3',
#   'mn_probable_case_count': '0',
#   'mn_hospitalized_count': '3',
#   'mn_death_count': '0',
#   'mn_probable_death_count': '0',
#   'mn_case_count_7day_avg': '1',
#   'mn_probable_case_count_7day_avg': '0',
#   'mn_all_case_count_7day_avg': '1',
#   'mn_hospitalized_count_7day_avg': '1',
#   'mn_death_count_7day_avg': '0',
#   'mn_all_death_count_7day_avg': '0',
#   'qn_case_count': '1',
#   'qn_probable_case_count': '0',
#   'qn_hospitalized_count': '2',
#   'qn_death_count': '0',
#   'qn_probable_death_count': '0',
#   'qn_case_count_7day_avg': '1',
#   'qn_probable_case_count_7day_avg': '0',
#   'qn_all_case_count_7day_avg': '1',
#   'qn_hospitalized_count_7day_avg': '1',
#   'qn_death_count_7day_avg': '0',
#   'qn_all_death_count_7day_avg': '0',
#   'si_case_count': '1',
#   'si_probable_case_count': '0',
#   'si_hospitalized_count': '1',
#   'si_death_count': '0',
#   'si_probable_death_count': '0',
#   'si_probable_case_count_7day_avg': '0',
#   'si_case_count_7day_avg': '0',
#   'si_all_case_count_7day_avg': '0',
#   'si_hospitalized_count_7day_avg': '0',
#   'si_death_count_7day_avg': '0',
#   'si_all_death_count_7day_avg': '0',
#   'incomplete': '0'},
#  {'date_of_interest': '2020-03-07T00:00:00.000',
#   'case_count': '7',
#   'probable_case_count': '0',
#   'hospitalized_count': '8',
#   'death_count': '0',
#   'probable_death_count': '0',
#   'case_count_7day_avg': '3',
#   'all_case_count_7day_avg': '3',
#   'hosp_count_7day_avg': '6',
#   'death_count_7day_avg': '0',
#   'all_death_count_7day_avg': '0',
#   'bx_case_count': '0',
#   'bx_probable_case_count': '0',
#   'bx_hospitalized_count': '1',
#   'bx_death_count': '0',
#   'bx_probable_death_count': '0',
#   'bx_case_count_7day_avg': '0',
#   'bx_probable_case_count_7day_avg': '0',
#   'bx_all_case_count_7day_avg': '0',
#   'bx_hospitalized_count_7day_avg': '1',
#   'bx_death_count_7day_avg': '0',
#   'bx_all_death_count_7day_avg': '0',
#   'bk_case_count': '2',
#   'bk_probable_case_count': '0',
#   'bk_hospitalized_count': '3',
#   'bk_death_count': '0',
#   'bk_probable_death_count': '0',
#   'bk_case_count_7day_avg': '1',
#   'bk_probable_case_count_7day_avg': '0',
#   'bk_all_case_count_7day_avg': '1',
#   'bk_hospitalized_count_7day_avg': '2',
#   'bk_death_count_7day_avg': '0',
#   'bk_all_death_count_7day_avg': '0',
#   'mn_case_count': '1',
#   'mn_probable_case_count': '0',
#   'mn_hospitalized_count': '0',
#   'mn_death_count': '0',
#   'mn_probable_death_count': '0',
#   'mn_case_count_7day_avg': '1',
#   'mn_probable_case_count_7day_avg': '0',
#   'mn_all_case_count_7day_avg': '1',
#   'mn_hospitalized_count_7day_avg': '1',
#   'mn_death_count_7day_avg': '0',
#   'mn_all_death_count_7day_avg': '0',
#   'qn_case_count': '3',
#   'qn_probable_case_count': '0',
#   'qn_hospitalized_count': '4',
#   'qn_death_count': '0',
#   'qn_probable_death_count': '0',
#   'qn_case_count_7day_avg': '1',
#   'qn_probable_case_count_7day_avg': '0',
#   'qn_all_case_count_7day_avg': '1',
#   'qn_hospitalized_count_7day_avg': '2',
#   'qn_death_count_7day_avg': '0',
#   'qn_all_death_count_7day_avg': '0',
#   'si_case_count': '1',
#   'si_probable_case_count': '0',
#   'si_hospitalized_count': '0',
#   'si_death_count': '0',
#   'si_probable_death_count': '0',
#   'si_probable_case_count_7day_avg': '0',
#   'si_case_count_7day_avg': '0',
#   'si_all_case_count_7day_avg': '0',
#   'si_hospitalized_count_7day_avg': '0',
#   'si_death_count_7day_avg': '0',
#   'si_all_death_count_7day_avg': '0',
#   'incomplete': '0'},
#  {'date_of_interest': '2020-03-08T00:00:00.000',
#   'case_count': '21',
#   'probable_case_count': '0',
#   'hospitalized_count': '18',
#   'death_count': '0',
#   'probable_death_count': '0',
#   'case_count_7day_avg': '6',
#   'all_case_count_7day_avg': '6',
#   'hosp_count_7day_avg': '8',
#   'death_count_7day_avg': '0',
#   'all_death_count_7day_avg': '0',
#   'bx_case_count': '3',
#   'bx_probable_case_count': '0',
#   'bx_hospitalized_count': '5',
#   'bx_death_count': '0',
#   'bx_probable_death_count': '0',
#   'bx_case_count_7day_avg': '1',
#   'bx_probable_case_count_7day_avg': '0',
#   'bx_all_case_count_7day_avg': '1',
#   'bx_hospitalized_count_7day_avg': '1',
#   'bx_death_count_7day_avg': '0',
#   'bx_all_death_count_7day_avg': '0',
#   'bk_case_count': '5',
#   'bk_probable_case_count': '0',
#   'bk_hospitalized_count': '8',
#   'bk_death_count': '0',
#   'bk_probable_death_count': '0',
#   'bk_case_count_7day_avg': '2',
#   'bk_probable_case_count_7day_avg': '0',
#   'bk_all_case_count_7day_avg': '2',
#   'bk_hospitalized_count_7day_avg': '3',
#   'bk_death_count_7day_avg': '0',
#   'bk_all_death_count_7day_avg': '0',
#   'mn_case_count': '6',
#   'mn_probable_case_count': '0',
#   'mn_hospitalized_count': '1',
#   'mn_death_count': '0',
#   'mn_probable_death_count': '0',
#   'mn_case_count_7day_avg': '2',
#   'mn_probable_case_count_7day_avg': '0',
#   'mn_all_case_count_7day_avg': '2',
#   'mn_hospitalized_count_7day_avg': '2',
#   'mn_death_count_7day_avg': '0',
#   'mn_all_death_count_7day_avg': '0',
#   'qn_case_count': '6',
#   'qn_probable_case_count': '0',
#   'qn_hospitalized_count': '4',
#   'qn_death_count': '0',
#   'qn_probable_death_count': '0',
#   'qn_case_count_7day_avg': '2',
#   'qn_probable_case_count_7day_avg': '0',
#   'qn_all_case_count_7day_avg': '2',
#   'qn_hospitalized_count_7day_avg': '2',
#   'qn_death_count_7day_avg': '0',
#   'qn_all_death_count_7day_avg': '0',
#   'si_case_count': '1',
#   'si_probable_case_count': '0',
#   'si_hospitalized_count': '0',
#   'si_death_count': '0',
#   'si_probable_death_count': '0',
#   'si_probable_case_count_7day_avg': '0',
#   'si_case_count_7day_avg': '0',
#   'si_all_case_count_7day_avg': '0',
#   'si_hospitalized_count_7day_avg': '0',
#   'si_death_count_7day_avg': '0',
#   'si_all_death_count_7day_avg': '0',
#   'incomplete': '0'},
#  {'date_of_interest': '2020-03-09T00:00:00.000',
#   'case_count': '57',
#   'probable_case_count': '0',
#   'hospitalized_count': '36',
#   'death_count': '0',
#   'probable_death_count': '0',
#   'case_count_7day_avg': '15',
#   'all_case_count_7day_avg': '15',
#   'hosp_count_7day_avg': '13',
#   'death_count_7day_avg': '0',
#   'all_death_count_7day_avg': '0',
#   'bx_case_count': '4',
#   'bx_probable_case_count': '0',
#   'bx_hospitalized_count': '7',
#   'bx_death_count': '0',
#   'bx_probable_death_count': '0',
#   'bx_case_count_7day_avg': '1',
#   'bx_probable_case_count_7day_avg': '0',
#   'bx_all_case_count_7day_avg': '1',
#   'bx_hospitalized_count_7day_avg': '2',
#   'bx_death_count_7day_avg': '0',
#   'bx_all_death_count_7day_avg': '0',
#   'bk_case_count': '16',
#   'bk_probable_case_count': '0',
#   'bk_hospitalized_count': '11',
#   'bk_death_count': '0',
#   'bk_probable_death_count': '0',
#   'bk_case_count_7day_avg': '4',
#   'bk_probable_case_count_7day_avg': '0',
#   'bk_all_case_count_7day_avg': '4',
#   'bk_hospitalized_count_7day_avg': '4',
#   'bk_death_count_7day_avg': '0',
#   'bk_all_death_count_7day_avg': '0',
#   'mn_case_count': '24',
#   'mn_probable_case_count': '0',
#   'mn_hospitalized_count': '9',
#   'mn_death_count': '0',
#   'mn_probable_death_count': '0',
#   'mn_case_count_7day_avg': '5',
#   'mn_probable_case_count_7day_avg': '0',
#   'mn_all_case_count_7day_avg': '5',
#   'mn_hospitalized_count_7day_avg': '3',
#   'mn_death_count_7day_avg': '0',
#   'mn_all_death_count_7day_avg': '0',
#   'qn_case_count': '10',
#   'qn_probable_case_count': '0',
#   'qn_hospitalized_count': '8',
#   'qn_death_count': '0',
#   'qn_probable_death_count': '0',
#   'qn_case_count_7day_avg': '3',
#   'qn_probable_case_count_7day_avg': '0',
#   'qn_all_case_count_7day_avg': '3',
#   'qn_hospitalized_count_7day_avg': '3',
#   'qn_death_count_7day_avg': '0',
#   'qn_all_death_count_7day_avg': '0',
#   'si_case_count': '3',
#   'si_probable_case_count': '0',
#   'si_hospitalized_count': '2',
#   'si_death_count': '0',
#   'si_probable_death_count': '0',
#   'si_probable_case_count_7day_avg': '0',
#   'si_case_count_7day_avg': '1',
#   'si_all_case_count_7day_avg': '1',
#   'si_hospitalized_count_7day_avg': '1',
#   'si_death_count_7day_avg': '0',
#   'si_all_death_count_7day_avg': '0',
#   'incomplete': '0'},
#  {'date_of_interest': '2020-03-10T00:00:00.000',
#   'case_count': '69',
#   'probable_case_count': '0',
#   'hospitalized_count': '60',
#   'death_count': '0',
#   'probable_death_count': '0',
#   'case_count_7day_avg': '24',
#   'all_case_count_7day_avg': '24',
#   'hosp_count_7day_avg': '21',
#   'death_count_7day_avg': '0',
#   'all_death_count_7day_avg': '0',
#   'bx_case_count': '8',
#   'bx_probable_case_count': '0',
#   'bx_hospitalized_count': '7',
#   'bx_death_count': '0',
#   'bx_probable_death_count': '0',
#   'bx_case_count_7day_avg': '2',
#   'bx_probable_case_count_7day_avg': '0',
#   'bx_all_case_count_7day_avg': '2',
#   'bx_hospitalized_count_7day_avg': '3',
#   'bx_death_count_7day_avg': '0',
#   'bx_all_death_count_7day_avg': '0',
#   'bk_case_count': '11',
#   'bk_probable_case_count': '0',
#   'bk_hospitalized_count': '13',
#   'bk_death_count': '0',
#   'bk_probable_death_count': '0',
#   'bk_case_count_7day_avg': '6',
#   'bk_probable_case_count_7day_avg': '0',
#   'bk_all_case_count_7day_avg': '6',
#   'bk_hospitalized_count_7day_avg': '6',
#   'bk_death_count_7day_avg': '0',
#   'bk_all_death_count_7day_avg': '0',
#   'mn_case_count': '24',
#   'mn_probable_case_count': '0',
#   'mn_hospitalized_count': '12',
#   'mn_death_count': '0',
#   'mn_probable_death_count': '0',
#   'mn_case_count_7day_avg': '9',
#   'mn_probable_case_count_7day_avg': '0',
#   'mn_all_case_count_7day_avg': '9',
#   'mn_hospitalized_count_7day_avg': '4',
#   'mn_death_count_7day_avg': '0',
#   'mn_all_death_count_7day_avg': '0',
#   'qn_case_count': '24',
#   'qn_probable_case_count': '0',
#   'qn_hospitalized_count': '23',
#   'qn_death_count': '0',
#   'qn_probable_death_count': '0',
#   'qn_case_count_7day_avg': '7',
#   'qn_probable_case_count_7day_avg': '0',
#   'qn_all_case_count_7day_avg': '7',
#   'qn_hospitalized_count_7day_avg': '6',
#   'qn_death_count_7day_avg': '0',
#   'qn_all_death_count_7day_avg': '0',
#   'si_case_count': '2',
#   'si_probable_case_count': '0',
#   'si_hospitalized_count': '5',
#   'si_death_count': '0',
#   'si_probable_death_count': '0',
#   'si_probable_case_count_7day_avg': '0',
#   'si_case_count_7day_avg': '1',
#   'si_all_case_count_7day_avg': '1',
#   'si_hospitalized_count_7day_avg': '1',
#   'si_death_count_7day_avg': '0',
#   'si_all_death_count_7day_avg': '0',
#   'incomplete': '0'},
#  {'date_of_interest': '2020-03-11T00:00:00.000',
#   'case_count': '155',
#   'probable_case_count': '0',
#   'hospitalized_count': '78',
#   'death_count': '1',
#   'probable_death_count': '0',
#   'case_count_7day_avg': '46',
#   'all_case_count_7day_avg': '46',
#   'hosp_count_7day_avg': '32',
#   'death_count_7day_avg': '0',
#   'all_death_count_7day_avg': '0',
#   'bx_case_count': '19',
#   'bx_probable_case_count': '0',
#   'bx_hospitalized_count': '23',
#   'bx_death_count': '0',
#   'bx_probable_death_count': '0',
#   'bx_case_count_7day_avg': '5',
#   'bx_probable_case_count_7day_avg': '0',
#   'bx_all_case_count_7day_avg': '5',
#   'bx_hospitalized_count_7day_avg': '6',
#   'bx_death_count_7day_avg': '0',
#   'bx_all_death_count_7day_avg': '0',
#   'bk_case_count': '31',
#   'bk_probable_case_count': '0',
#   'bk_hospitalized_count': '11',
#   'bk_death_count': '0',
#   'bk_probable_death_count': '0',
#   'bk_case_count_7day_avg': '10',
#   'bk_probable_case_count_7day_avg': '0',
#   'bk_all_case_count_7day_avg': '10',
#   'bk_hospitalized_count_7day_avg': '7',
#   'bk_death_count_7day_avg': '0',
#   'bk_all_death_count_7day_avg': '0',
#   'mn_case_count': '62',
#   'mn_probable_case_count': '0',
#   'mn_hospitalized_count': '19',
#   'mn_death_count': '0',
#   'mn_probable_death_count': '0',
#   'mn_case_count_7day_avg': '17',
#   'mn_probable_case_count_7day_avg': '0',
#   'mn_all_case_count_7day_avg': '17',
#   'mn_hospitalized_count_7day_avg': '7',
#   'mn_death_count_7day_avg': '0',
#   'mn_all_death_count_7day_avg': '0',
#   'qn_case_count': '40',
#   'qn_probable_case_count': '0',
#   'qn_hospitalized_count': '23',
#   'qn_death_count': '1',
#   'qn_probable_death_count': '0',
#   'qn_case_count_7day_avg': '12',
#   'qn_probable_case_count_7day_avg': '0',
#   'qn_all_case_count_7day_avg': '12',
#   'qn_hospitalized_count_7day_avg': '10',
#   'qn_death_count_7day_avg': '0',
#   'qn_all_death_count_7day_avg': '0',
#   'si_case_count': '3',
#   'si_probable_case_count': '0',
#   'si_hospitalized_count': '2',
#   'si_death_count': '0',
#   'si_probable_death_count': '0',
#   'si_probable_case_count_7day_avg': '0',
#   'si_case_count_7day_avg': '2',
#   'si_all_case_count_7day_avg': '2',
#   'si_hospitalized_count_7day_avg': '2',
#   'si_death_count_7day_avg': '0',
#   'si_all_death_count_7day_avg': '0',
#   'incomplete': '0'},
#  {'date_of_interest': '2020-03-12T00:00:00.000',
#   'case_count': '355',
#   'probable_case_count': '0',
#   'hospitalized_count': '105',
#   'death_count': '0',
#   'probable_death_count': '0',
#   'case_count_7day_avg': '96',
#   'all_case_count_7day_avg': '96',
#   'hosp_count_7day_avg': '45',
#   'death_count_7day_avg': '0',
#   'all_death_count_7day_avg': '0',
#   'bx_case_count': '29',
#   'bx_probable_case_count': '0',
#   'bx_hospitalized_count': '19',
#   'bx_death_count': '0',
#   'bx_probable_death_count': '0',
#   'bx_case_count_7day_avg': '9',
#   'bx_probable_case_count_7day_avg': '0',
#   'bx_all_case_count_7day_avg': '9',
#   'bx_hospitalized_count_7day_avg': '9',
#   'bx_death_count_7day_avg': '0',
#   'bx_all_death_count_7day_avg': '0',
#   'bk_case_count': '96',
#   'bk_probable_case_count': '0',
#   'bk_hospitalized_count': '33',
#   'bk_death_count': '0',
#   'bk_probable_death_count': '0',
#   'bk_case_count_7day_avg': '23',
#   'bk_probable_case_count_7day_avg': '0',
#   'bk_all_case_count_7day_avg': '23',
#   'bk_hospitalized_count_7day_avg': '11',
#   'bk_death_count_7day_avg': '0',
#   'bk_all_death_count_7day_avg': '0',
#   'mn_case_count': '137',
#   'mn_probable_case_count': '0',
#   'mn_hospitalized_count': '16',
#   'mn_death_count': '0',
#   'mn_probable_death_count': '0',
#   'mn_case_count_7day_avg': '37',
#   'mn_probable_case_count_7day_avg': '0',
#   'mn_all_case_count_7day_avg': '37',
#   'mn_hospitalized_count_7day_avg': '9',
#   'mn_death_count_7day_avg': '0',
#   'mn_all_death_count_7day_avg': '0',
#   'qn_case_count': '80',
#   'qn_probable_case_count': '0',
#   'qn_hospitalized_count': '35',
#   'qn_death_count': '0',
#   'qn_probable_death_count': '0',
#   'qn_case_count_7day_avg': '23',
#   'qn_probable_case_count_7day_avg': '0',
#   'qn_all_case_count_7day_avg': '23',
#   'qn_hospitalized_count_7day_avg': '14',
#   'qn_death_count_7day_avg': '0',
#   'qn_all_death_count_7day_avg': '0',
#   'si_case_count': '13',
#   'si_probable_case_count': '0',
#   'si_hospitalized_count': '3',
#   'si_death_count': '0',
#   'si_probable_death_count': '0',
#   'si_probable_case_count_7day_avg': '0',
#   'si_case_count_7day_avg': '3',
#   'si_all_case_count_7day_avg': '3',
#   'si_hospitalized_count_7day_avg': '2',
#   'si_death_count_7day_avg': '0',
#   'si_all_death_count_7day_avg': '0',
#   'incomplete': '0'},
#  {'date_of_interest': '2020-03-13T00:00:00.000',
#   'case_count': '619',
#   'probable_case_count': '0',
#   'hospitalized_count': '151',
#   'death_count': '0',
#   'probable_death_count': '0',
#   'case_count_7day_avg': '183',
#   'all_case_count_7day_avg': '183',
#   'hosp_count_7day_avg': '65',
#   'death_count_7day_avg': '0',
#   'all_death_count_7day_avg': '0',
#   'bx_case_count': '79',
#   'bx_probable_case_count': '0',
#   'bx_hospitalized_count': '26',
#   'bx_death_count': '0',
#   'bx_probable_death_count': '0',
#   'bx_case_count_7day_avg': '20',
#   'bx_probable_case_count_7day_avg': '0',
#   'bx_all_case_count_7day_avg': '20',
#   'bx_hospitalized_count_7day_avg': '13',
#   'bx_death_count_7day_avg': '0',
#   'bx_all_death_count_7day_avg': '0',
#   'bk_case_count': '166',
#   'bk_probable_case_count': '0',
#   'bk_hospitalized_count': '44',
#   'bk_death_count': '0',
#   'bk_probable_death_count': '0',
#   'bk_case_count_7day_avg': '47',
#   'bk_probable_case_count_7day_avg': '0',
#   'bk_all_case_count_7day_avg': '47',
#   'bk_hospitalized_count_7day_avg': '18',
#   'bk_death_count_7day_avg': '0',
#   'bk_all_death_count_7day_avg': '0',
#   'mn_case_count': '182',
#   'mn_probable_case_count': '0',
#   'mn_hospitalized_count': '31',
#   'mn_death_count': '0',
#   'mn_probable_death_count': '0',
#   'mn_case_count_7day_avg': '62',
#   'mn_probable_case_count_7day_avg': '0',
#   'mn_all_case_count_7day_avg': '62',
#   'mn_hospitalized_count_7day_avg': '13',
#   'mn_death_count_7day_avg': '0',
#   'mn_all_death_count_7day_avg': '0',
#   'qn_case_count': '166',
#   'qn_probable_case_count': '0',
#   'qn_hospitalized_count': '49',
#   'qn_death_count': '0',
#   'qn_probable_death_count': '0',
#   'qn_case_count_7day_avg': '47',
#   'qn_probable_case_count_7day_avg': '0',
#   'qn_all_case_count_7day_avg': '47',
#   'qn_hospitalized_count_7day_avg': '21',
#   'qn_death_count_7day_avg': '0',
#   'qn_all_death_count_7day_avg': '0',
#   'si_case_count': '26',
#   'si_probable_case_count': '0',
#   'si_hospitalized_count': '2',
#   'si_death_count': '0',
#   'si_probable_death_count': '0',
#   'si_probable_case_count_7day_avg': '0',
#   'si_case_count_7day_avg': '7',
#   'si_all_case_count_7day_avg': '7',
#   'si_hospitalized_count_7day_avg': '2',
#   'si_death_count_7day_avg': '0',
#   'si_all_death_count_7day_avg': '0',
#   'incomplete': '0'},
#  {'date_of_interest': '2020-03-14T00:00:00.000',
#   'case_count': '642',
#   'probable_case_count': '1',
#   'hospitalized_count': '176',
#   'death_count': '2',
#   'probable_death_count': '1',
#   'case_count_7day_avg': '274',
#   'all_case_count_7day_avg': '274',
#   'hosp_count_7day_avg': '89',
#   'death_count_7day_avg': '0',
#   'all_death_count_7day_avg': '1',
#   'bx_case_count': '86',
#   'bx_probable_case_count': '0',
#   'bx_hospitalized_count': '22',
#   'bx_death_count': '0',
#   'bx_probable_death_count': '0',
#   'bx_case_count_7day_avg': '33',
#   'bx_probable_case_count_7day_avg': '0',
#   'bx_all_case_count_7day_avg': '33',
#   'bx_hospitalized_count_7day_avg': '16',
#   'bx_death_count_7day_avg': '0',
#   'bx_all_death_count_7day_avg': '0',
#   'bk_case_count': '163',
#   'bk_probable_case_count': '0',
#   'bk_hospitalized_count': '40',
#   'bk_death_count': '1',
#   'bk_probable_death_count': '0',
#   'bk_case_count_7day_avg': '70',
#   'bk_probable_case_count_7day_avg': '0',
#   'bk_all_case_count_7day_avg': '70',
#   'bk_hospitalized_count_7day_avg': '23',
#   'bk_death_count_7day_avg': '0',
#   'bk_all_death_count_7day_avg': '0',
#   'mn_case_count': '176',
#   'mn_probable_case_count': '1',
#   'mn_hospitalized_count': '36',
#   'mn_death_count': '0',
#   'mn_probable_death_count': '1',
#   'mn_case_count_7day_avg': '87',
#   'mn_probable_case_count_7day_avg': '0',
#   'mn_all_case_count_7day_avg': '87',
#   'mn_hospitalized_count_7day_avg': '18',
#   'mn_death_count_7day_avg': '0',
#   'mn_all_death_count_7day_avg': '0',
#   'qn_case_count': '194',
#   'qn_probable_case_count': '0',
#   'qn_hospitalized_count': '72',
#   'qn_death_count': '1',
#   'qn_probable_death_count': '0',
#   'qn_case_count_7day_avg': '74',
#   'qn_probable_case_count_7day_avg': '0',
#   'qn_all_case_count_7day_avg': '74',
#   'qn_hospitalized_count_7day_avg': '31',
#   'qn_death_count_7day_avg': '0',
#   'qn_all_death_count_7day_avg': '0',
#   'si_case_count': '23',
#   'si_probable_case_count': '0',
#   'si_hospitalized_count': '7',
#   'si_death_count': '0',
#   'si_probable_death_count': '0',
#   'si_probable_case_count_7day_avg': '0',
#   'si_case_count_7day_avg': '10',
#   'si_all_case_count_7day_avg': '10',
#   'si_hospitalized_count_7day_avg': '3',
#   'si_death_count_7day_avg': '0',
#   'si_all_death_count_7day_avg': '0',
#   'incomplete': '0'},
#  {'date_of_interest': '2020-03-15T00:00:00.000',
#   'case_count': '1034',
#   'probable_case_count': '0',
#   'hospitalized_count': '210',
#   'death_count': '4',
#   'probable_death_count': '0',
#   'case_count_7day_avg': '419',
#   'all_case_count_7day_avg': '419',
#   'hosp_count_7day_avg': '117',
#   'death_count_7day_avg': '1',
#   'all_death_count_7day_avg': '1',
#   'bx_case_count': '119',
#   'bx_probable_case_count': '0',
#   'bx_hospitalized_count': '37',
#   'bx_death_count': '1',
#   'bx_probable_death_count': '0',
#   'bx_case_count_7day_avg': '49',
#   'bx_probable_case_count_7day_avg': '0',
#   'bx_all_case_count_7day_avg': '49',
#   'bx_hospitalized_count_7day_avg': '20',
#   'bx_death_count_7day_avg': '0',
#   'bx_all_death_count_7day_avg': '0',
#   'bk_case_count': '432',
#   'bk_probable_case_count': '0',
#   'bk_hospitalized_count': '53',
#   'bk_death_count': '0',
#   'bk_probable_death_count': '0',
#   'bk_case_count_7day_avg': '131',
#   'bk_probable_case_count_7day_avg': '0',
#   'bk_all_case_count_7day_avg': '131',
#   'bk_hospitalized_count_7day_avg': '29',
#   'bk_death_count_7day_avg': '0',
#   'bk_all_death_count_7day_avg': '0',
#   'mn_case_count': '205',
#   'mn_probable_case_count': '0',
#   'mn_hospitalized_count': '33',
#   'mn_death_count': '2',
#   'mn_probable_death_count': '0',
#   'mn_case_count_7day_avg': '116',
#   'mn_probable_case_count_7day_avg': '0',
#   'mn_all_case_count_7day_avg': '116',
#   'mn_hospitalized_count_7day_avg': '22',
#   'mn_death_count_7day_avg': '0',
#   'mn_all_death_count_7day_avg': '0',
#   'qn_case_count': '231',
#   'qn_probable_case_count': '0',
#   'qn_hospitalized_count': '67',
#   'qn_death_count': '1',
#   'qn_probable_death_count': '0',
#   'qn_case_count_7day_avg': '106',
#   'qn_probable_case_count_7day_avg': '0',
#   'qn_all_case_count_7day_avg': '106',
#   'qn_hospitalized_count_7day_avg': '40',
#   'qn_death_count_7day_avg': '0',
#   'qn_all_death_count_7day_avg': '0',
#   'si_case_count': '47',
#   'si_probable_case_count': '0',
#   'si_hospitalized_count': '20',
#   'si_death_count': '0',
#   'si_probable_death_count': '0',
#   'si_probable_case_count_7day_avg': '0',
#   'si_case_count_7day_avg': '17',
#   'si_all_case_count_7day_avg': '17',
#   'si_hospitalized_count_7day_avg': '6',
#   'si_death_count_7day_avg': '0',
#   'si_all_death_count_7day_avg': '0',
#   'incomplete': '0'},
#  {'date_of_interest': '2020-03-16T00:00:00.000',
#   'case_count': '2121',
#   'probable_case_count': '2',
#   'hospitalized_count': '337',
#   'death_count': '7',
#   'probable_death_count': '2',
#   'case_count_7day_avg': '714',
#   'all_case_count_7day_avg': '714',
#   'hosp_count_7day_avg': '160',
#   'death_count_7day_avg': '2',
#   'all_death_count_7day_avg': '2',
#   'bx_case_count': '305',
#   'bx_probable_case_count': '0',
#   'bx_hospitalized_count': '72',
#   'bx_death_count': '3',
#   'bx_probable_death_count': '0',
#   'bx_case_count_7day_avg': '92',
#   'bx_probable_case_count_7day_avg': '0',
#   'bx_all_case_count_7day_avg': '92',
#   'bx_hospitalized_count_7day_avg': '29',
#   'bx_death_count_7day_avg': '1',
#   'bx_all_death_count_7day_avg': '1',
#   'bk_case_count': '740',
#   'bk_probable_case_count': '1',
#   'bk_hospitalized_count': '92',
#   'bk_death_count': '1',
#   'bk_probable_death_count': '1',
#   'bk_case_count_7day_avg': '234',
#   'bk_probable_case_count_7day_avg': '0',
#   'bk_all_case_count_7day_avg': '234',
#   'bk_hospitalized_count_7day_avg': '41',
#   'bk_death_count_7day_avg': '0',
#   'bk_all_death_count_7day_avg': '0',
#   'mn_case_count': '457',
#   'mn_probable_case_count': '0',
#   'mn_hospitalized_count': '45',
#   'mn_death_count': '0',
#   'mn_probable_death_count': '0',
#   'mn_case_count_7day_avg': '178',
#   'mn_probable_case_count_7day_avg': '0',
#   'mn_all_case_count_7day_avg': '178',
#   'mn_hospitalized_count_7day_avg': '27',
#   'mn_death_count_7day_avg': '0',
#   'mn_all_death_count_7day_avg': '0',
#   'qn_case_count': '528',
#   'qn_probable_case_count': '1',
#   'qn_hospitalized_count': '114',
#   'qn_death_count': '3',
#   'qn_probable_death_count': '1',
#   'qn_case_count_7day_avg': '180',
#   'qn_probable_case_count_7day_avg': '0',
#   'qn_all_case_count_7day_avg': '181',
#   'qn_hospitalized_count_7day_avg': '55',
#   'qn_death_count_7day_avg': '1',
#   'qn_all_death_count_7day_avg': '1',
#   'si_case_count': '91',
#   'si_probable_case_count': '0',
#   'si_hospitalized_count': '15',
#   'si_death_count': '0',
#   'si_probable_death_count': '0',
#   'si_probable_case_count_7day_avg': '0',
#   'si_case_count_7day_avg': '29',
#   'si_all_case_count_7day_avg': '29',
#   'si_hospitalized_count_7day_avg': '8',
#   'si_death_count_7day_avg': '0',
#   'si_all_death_count_7day_avg': '0',
#   'incomplete': '0'},
#  {'date_of_interest': '2020-03-17T00:00:00.000',
#   'case_count': '2451',
#   'probable_case_count': '4',
#   'hospitalized_count': '382',
#   'death_count': '8',
#   'probable_death_count': '4',
#   'case_count_7day_avg': '1054',
#   'all_case_count_7day_avg': '1055',
#   'hosp_count_7day_avg': '206',
#   'death_count_7day_avg': '3',
#   'all_death_count_7day_avg': '4',
#   'bx_case_count': '343',
#   'bx_probable_case_count': '0',
#   'bx_hospitalized_count': '60',
#   'bx_death_count': '1',
#   'bx_probable_death_count': '0',
#   'bx_case_count_7day_avg': '140',
#   'bx_probable_case_count_7day_avg': '0',
#   'bx_all_case_count_7day_avg': '140',
#   'bx_hospitalized_count_7day_avg': '37',
#   'bx_death_count_7day_avg': '1',
#   'bx_all_death_count_7day_avg': '1',
#   'bk_case_count': '783',
#   'bk_probable_case_count': '3',
#   'bk_hospitalized_count': '98',
#   'bk_death_count': '4',
#   'bk_probable_death_count': '3',
#   'bk_case_count_7day_avg': '344',
#   'bk_probable_case_count_7day_avg': '1',
#   'bk_all_case_count_7day_avg': '345',
#   'bk_hospitalized_count_7day_avg': '53',
#   'bk_death_count_7day_avg': '1',
#   'bk_all_death_count_7day_avg': '1',
#   'mn_case_count': '567',
#   'mn_probable_case_count': '0',
#   'mn_hospitalized_count': '76',
#   'mn_death_count': '0',
#   'mn_probable_death_count': '0',
#   'mn_case_count_7day_avg': '255',
#   'mn_probable_case_count_7day_avg': '0',
#   'mn_all_case_count_7day_avg': '255',
#   'mn_hospitalized_count_7day_avg': '37',
#   'mn_death_count_7day_avg': '0',
#   'mn_all_death_count_7day_avg': '0',
#   'qn_case_count': '650',
#   'qn_probable_case_count': '0',
#   'qn_hospitalized_count': '128',
#   'qn_death_count': '3',
#   'qn_probable_death_count': '0',
#   'qn_case_count_7day_avg': '270',
#   'qn_probable_case_count_7day_avg': '0',
#   'qn_all_case_count_7day_avg': '270',
#   'qn_hospitalized_count_7day_avg': '70',
#   'qn_death_count_7day_avg': '1',
#   'qn_all_death_count_7day_avg': '1',
#   'si_case_count': '108',
#   'si_probable_case_count': '1',
#   'si_hospitalized_count': '23',
#   'si_death_count': '0',
#   'si_probable_death_count': '1',
#   'si_probable_case_count_7day_avg': '0',
#   'si_case_count_7day_avg': '44',
#   'si_all_case_count_7day_avg': '45',
#   'si_hospitalized_count_7day_avg': '10',
#   'si_death_count_7day_avg': '0',
#   'si_all_death_count_7day_avg': '0',
#   'incomplete': '0'},
#  {'date_of_interest': '2020-03-18T00:00:00.000',
#   'case_count': '2971',
#   'probable_case_count': '5',
#   'hospitalized_count': '491',
#   'death_count': '20',
#   'probable_death_count': '4',
#   'case_count_7day_avg': '1456',
#   'all_case_count_7day_avg': '1458',
#   'hosp_count_7day_avg': '265',
#   'death_count_7day_avg': '6',
#   'all_death_count_7day_avg': '7',
#   'bx_case_count': '482',
#   'bx_probable_case_count': '1',
#   'bx_hospitalized_count': '110',
#   'bx_death_count': '1',
#   'bx_probable_death_count': '1',
#   'bx_case_count_7day_avg': '206',
#   'bx_probable_case_count_7day_avg': '0',
#   'bx_all_case_count_7day_avg': '206',
#   'bx_hospitalized_count_7day_avg': '49',
#   'bx_death_count_7day_avg': '1',
#   'bx_all_death_count_7day_avg': '1',
#   'bk_case_count': '965',
#   'bk_probable_case_count': '3',
#   'bk_hospitalized_count': '123',
#   'bk_death_count': '6',
#   'bk_probable_death_count': '2',
#   'bk_case_count_7day_avg': '478',
#   'bk_probable_case_count_7day_avg': '1',
#   'bk_all_case_count_7day_avg': '479',
#   'bk_hospitalized_count_7day_avg': '69',
#   'bk_death_count_7day_avg': '2',
#   'bk_all_death_count_7day_avg': '3',
#   'mn_case_count': '538',
#   'mn_probable_case_count': '1',
#   'mn_hospitalized_count': '87',
#   'mn_death_count': '4',
#   'mn_probable_death_count': '1',
#   'mn_case_count_7day_avg': '323',
#   'mn_probable_case_count_7day_avg': '0',
#   'mn_all_case_count_7day_avg': '323',
#   'mn_hospitalized_count_7day_avg': '46',
#   'mn_death_count_7day_avg': '1',
#   'mn_all_death_count_7day_avg': '1',
#   'qn_case_count': '835',
#   'qn_probable_case_count': '0',
#   'qn_hospitalized_count': '152',
#   'qn_death_count': '9',
#   'qn_probable_death_count': '0',
#   'qn_case_count_7day_avg': '383',
#   'qn_probable_case_count_7day_avg': '0',
#   'qn_all_case_count_7day_avg': '384',
#   'qn_hospitalized_count_7day_avg': '88',
#   'qn_death_count_7day_avg': '2',
#   'qn_all_death_count_7day_avg': '3',
#   'si_case_count': '150',
#   'si_probable_case_count': '0',
#   'si_hospitalized_count': '22',
#   'si_death_count': '0',
#   'si_probable_death_count': '0',
#   'si_probable_case_count_7day_avg': '0',
#   'si_case_count_7day_avg': '65',
#   'si_all_case_count_7day_avg': '66',
#   'si_hospitalized_count_7day_avg': '13',
#   'si_death_count_7day_avg': '0',
#   'si_all_death_count_7day_avg': '0',
#   'incomplete': '0'},
#  {'date_of_interest': '2020-03-19T00:00:00.000',
#   'case_count': '3706',
#   'probable_case_count': '4',
#   'hospitalized_count': '629',
#   'death_count': '24',
#   'probable_death_count': '3',
#   'case_count_7day_avg': '1935',
#   'all_case_count_7day_avg': '1937',
#   'hosp_count_7day_avg': '339',
#   'death_count_7day_avg': '9',
#   'all_death_count_7day_avg': '11',
#   'bx_case_count': '623',
#   'bx_probable_case_count': '3',
#   'bx_hospitalized_count': '135',
#   'bx_death_count': '4',
#   'bx_probable_death_count': '3',
#   'bx_case_count_7day_avg': '291',
#   'bx_probable_case_count_7day_avg': '1',
#   'bx_all_case_count_7day_avg': '292',
#   'bx_hospitalized_count_7day_avg': '66',
#   'bx_death_count_7day_avg': '1',
#   'bx_all_death_count_7day_avg': '2',
#   'bk_case_count': '1204',
#   'bk_probable_case_count': '0',
#   'bk_hospitalized_count': '157',
#   'bk_death_count': '6',
#   'bk_probable_death_count': '0',
#   'bk_case_count_7day_avg': '636',
#   'bk_probable_case_count_7day_avg': '1',
#   'bk_all_case_count_7day_avg': '637',
#   'bk_hospitalized_count_7day_avg': '87',
#   'bk_death_count_7day_avg': '3',
#   'bk_all_death_count_7day_avg': '3',
#   'mn_case_count': '555',
#   'mn_probable_case_count': '1',
#   'mn_hospitalized_count': '105',
#   'mn_death_count': '4',
#   'mn_probable_death_count': '0',
#   'mn_case_count_7day_avg': '383',
#   'mn_probable_case_count_7day_avg': '0',
#   'mn_all_case_count_7day_avg': '383',
#   'mn_hospitalized_count_7day_avg': '59',
#   'mn_death_count_7day_avg': '1',
#   'mn_all_death_count_7day_avg': '2',
#   'qn_case_count': '1065',
#   'qn_probable_case_count': '0',
#   'qn_hospitalized_count': '208',
#   'qn_death_count': '6',
#   'qn_probable_death_count': '0',
#   'qn_case_count_7day_avg': '524',
#   'qn_probable_case_count_7day_avg': '0',
#   'qn_all_case_count_7day_avg': '524',
#   'qn_hospitalized_count_7day_avg': '113',
#   'qn_death_count_7day_avg': '3',
#   'qn_all_death_count_7day_avg': '3',
#   'si_case_count': '258',
#   'si_probable_case_count': '0',
#   'si_hospitalized_count': '26',
#   'si_death_count': '4',
#   'si_probable_death_count': '0',
#   'si_probable_case_count_7day_avg': '0',
#   'si_case_count_7day_avg': '100',
#   'si_all_case_count_7day_avg': '101',
#   'si_hospitalized_count_7day_avg': '16',
#   'si_death_count_7day_avg': '1',
#   'si_all_death_count_7day_avg': '1',
#   'incomplete': '0'},
#  {'date_of_interest': '2020-03-20T00:00:00.000',
#   'case_count': '4007',
#   'probable_case_count': '3',
#   'hospitalized_count': '732',
#   'death_count': '47',
#   'probable_death_count': '3',
#   'case_count_7day_avg': '2419',
#   'all_case_count_7day_avg': '2422',
#   'hosp_count_7day_avg': '422',
#   'death_count_7day_avg': '16',
#   'all_death_count_7day_avg': '18',
#   'bx_case_count': '723',
#   'bx_probable_case_count': '0',
#   'bx_hospitalized_count': '126',
#   'bx_death_count': '13',
#   'bx_probable_death_count': '0',
#   'bx_case_count_7day_avg': '383',
#   'bx_probable_case_count_7day_avg': '1',
#   'bx_all_case_count_7day_avg': '384',
#   'bx_hospitalized_count_7day_avg': '80',
#   'bx_death_count_7day_avg': '3',
#   'bx_all_death_count_7day_avg': '4',
#   'bk_case_count': '1136',
#   'bk_probable_case_count': '0',
#   'bk_hospitalized_count': '220',
#   'bk_death_count': '11',
#   'bk_probable_death_count': '0',
#   'bk_case_count_7day_avg': '775',
#   'bk_probable_case_count_7day_avg': '1',
#   'bk_all_case_count_7day_avg': '776',
#   'bk_hospitalized_count_7day_avg': '112',
#   'bk_death_count_7day_avg': '4',
#   'bk_all_death_count_7day_avg': '5',
#   'mn_case_count': '653',
#   'mn_probable_case_count': '1',
#   'mn_hospitalized_count': '112',
#   'mn_death_count': '11',
#   'mn_probable_death_count': '1',
#   'mn_case_count_7day_avg': '450',
#   'mn_probable_case_count_7day_avg': '1',
#   'mn_all_case_count_7day_avg': '451',
#   'mn_hospitalized_count_7day_avg': '71',
#   'mn_death_count_7day_avg': '3',
#   'mn_all_death_count_7day_avg': '3',
#   'qn_case_count': '1185',
#   'qn_probable_case_count': '1',
#   'qn_hospitalized_count': '247',
#   'qn_death_count': '9',
#   'qn_probable_death_count': '1',
#   'qn_case_count_7day_avg': '670',
#   'qn_probable_case_count_7day_avg': '0',
#   'qn_all_case_count_7day_avg': '670',
#   'qn_hospitalized_count_7day_avg': '141',
#   'qn_death_count_7day_avg': '5',
#   'qn_all_death_count_7day_avg': '5',
#   'si_case_count': '310',
#   'si_probable_case_count': '1',
#   'si_hospitalized_count': '33',
#   'si_death_count': '3',
#   'si_probable_death_count': '1',
#   'si_probable_case_count_7day_avg': '0',
#   'si_case_count_7day_avg': '141',
#   'si_all_case_count_7day_avg': '141',
#   'si_hospitalized_count_7day_avg': '21',
#   'si_death_count_7day_avg': '1',
#   'si_all_death_count_7day_avg': '1',
#   'incomplete': '0'},
#  {'date_of_interest': '2020-03-21T00:00:00.000',
#   'case_count': '2639',
#   'probable_case_count': '7',
#   'hospitalized_count': '731',
#   'death_count': '44',
#   'probable_death_count': '7',
#   'case_count_7day_avg': '2704',
#   'all_case_count_7day_avg': '2708',
#   'hosp_count_7day_avg': '502',
#   'death_count_7day_avg': '22',
#   'all_death_count_7day_avg': '25',
#   'bx_case_count': '491',
#   'bx_probable_case_count': '2',
#   'bx_hospitalized_count': '158',
#   'bx_death_count': '12',
#   'bx_probable_death_count': '2',
#   'bx_case_count_7day_avg': '441',
#   'bx_probable_case_count_7day_avg': '1',
#   'bx_all_case_count_7day_avg': '442',
#   'bx_hospitalized_count_7day_avg': '100',
#   'bx_death_count_7day_avg': '5',
# ...
#   'hospitalized_count': '127',
#   'death_count': '15',
#   'probable_death_count': '0',
#   'case_count_7day_avg': '2007',
#   'all_case_count_7day_avg': '2569',
#   'hosp_count_7day_avg': '139',
#   'death_count_7day_avg': '14',
#   'all_death_count_7day_avg': '16',
#   'bx_case_count': '275',
#   'bx_probable_case_count': '42',
#   'bx_hospitalized_count': '23',
#   'bx_death_count': '5',
#   'bx_probable_death_count': '0',
#   'bx_case_count_7day_avg': '338',
#   'bx_probable_case_count_7day_avg': '104',
#   'bx_all_case_count_7day_avg': '442',
#   'bx_hospitalized_count_7day_avg': '30',
#   'bx_death_count_7day_avg': '2',
#   'bx_all_death_count_7day_avg': '2',
#   'bk_case_count': '503',
#   'bk_probable_case_count': '57',
#   'bk_hospitalized_count': '46',
#   'bk_death_count': '4',
#   'bk_probable_death_count': '0',
#   'bk_case_count_7day_avg': '599',
#   'bk_probable_case_count_7day_avg': '159',
#   'bk_all_case_count_7day_avg': '758',
#   'bk_hospitalized_count_7day_avg': '43',
#   'bk_death_count_7day_avg': '4',
#   'bk_all_death_count_7day_avg': '5',
#   'mn_case_count': '281',
#   'mn_probable_case_count': '38',
#   'mn_hospitalized_count': '18',
#   'mn_death_count': '0',
#   'mn_probable_death_count': '0',
#   'mn_case_count_7day_avg': '384',
#   'mn_probable_case_count_7day_avg': '102',
#   'mn_all_case_count_7day_avg': '486',
#   'mn_hospitalized_count_7day_avg': '25',
#   'mn_death_count_7day_avg': '2',
#   'mn_all_death_count_7day_avg': '2',
#   'qn_case_count': '442',
#   'qn_probable_case_count': '114',
#   'qn_hospitalized_count': '36',
#   'qn_death_count': '5',
#   'qn_probable_death_count': '0',
#   'qn_case_count_7day_avg': '584',
#   'qn_probable_case_count_7day_avg': '168',
#   'qn_all_case_count_7day_avg': '751',
#   'qn_hospitalized_count_7day_avg': '36',
#   'qn_death_count_7day_avg': '5',
#   'qn_all_death_count_7day_avg': '5',
#   'si_case_count': '68',
#   'si_probable_case_count': '11',
#   'si_hospitalized_count': '5',
#   'si_death_count': '1',
#   'si_probable_death_count': '0',
#   'si_probable_case_count_7day_avg': '30',
#   'si_case_count_7day_avg': '102',
#   'si_all_case_count_7day_avg': '131',
#   'si_hospitalized_count_7day_avg': '8',
#   'si_death_count_7day_avg': '1',
#   'si_all_death_count_7day_avg': '1',
#   'incomplete': '0'},
#  {'date_of_interest': '2022-11-19T00:00:00.000',
#   'case_count': '1161',
#   'probable_case_count': '397',
#   'hospitalized_count': '89',
#   'death_count': '17',
#   'probable_death_count': '2',
#   'case_count_7day_avg': '1953',
#   'all_case_count_7day_avg': '2499',
#   'hosp_count_7day_avg': '135',
#   'death_count_7day_avg': '15',
#   'all_death_count_7day_avg': '16',
#   'bx_case_count': '174',
#   'bx_probable_case_count': '93',
#   'bx_hospitalized_count': '13',
#   'bx_death_count': '2',
#   'bx_probable_death_count': '0',
#   'bx_case_count_7day_avg': '333',
#   'bx_probable_case_count_7day_avg': '106',
#   'bx_all_case_count_7day_avg': '439',
#   'bx_hospitalized_count_7day_avg': '28',
#   'bx_death_count_7day_avg': '2',
#   'bx_all_death_count_7day_avg': '2',
#   'bk_case_count': '330',
#   'bk_probable_case_count': '92',
#   'bk_hospitalized_count': '30',
#   'bk_death_count': '7',
#   'bk_probable_death_count': '1',
#   'bk_case_count_7day_avg': '580',
#   'bk_probable_case_count_7day_avg': '150',
#   'bk_all_case_count_7day_avg': '730',
#   'bk_hospitalized_count_7day_avg': '41',
#   'bk_death_count_7day_avg': '5',
#   'bk_all_death_count_7day_avg': '5',
#   'mn_case_count': '214',
#   'mn_probable_case_count': '83',
#   'mn_hospitalized_count': '21',
#   'mn_death_count': '2',
#   'mn_probable_death_count': '0',
#   'mn_case_count_7day_avg': '377',
#   'mn_probable_case_count_7day_avg': '99',
#   'mn_all_case_count_7day_avg': '476',
#   'mn_hospitalized_count_7day_avg': '25',
#   'mn_death_count_7day_avg': '2',
#   'mn_all_death_count_7day_avg': '2',
#   'qn_case_count': '381',
#   'qn_probable_case_count': '107',
#   'qn_hospitalized_count': '22',
#   'qn_death_count': '4',
#   'qn_probable_death_count': '1',
#   'qn_case_count_7day_avg': '567',
#   'qn_probable_case_count_7day_avg': '163',
#   'qn_all_case_count_7day_avg': '730',
#   'qn_hospitalized_count_7day_avg': '35',
#   'qn_death_count_7day_avg': '5',
#   'qn_all_death_count_7day_avg': '5',
#   'si_case_count': '62',
#   'si_probable_case_count': '22',
#   'si_hospitalized_count': '5',
#   'si_death_count': '2',
#   'si_probable_death_count': '0',
#   'si_probable_case_count_7day_avg': '27',
#   'si_case_count_7day_avg': '95',
#   'si_all_case_count_7day_avg': '122',
#   'si_hospitalized_count_7day_avg': '7',
#   'si_death_count_7day_avg': '1',
#   'si_all_death_count_7day_avg': '1',
#   'incomplete': '0'},
#  {'date_of_interest': '2022-11-20T00:00:00.000',
#   'case_count': '1340',
#   'probable_case_count': '556',
#   'hospitalized_count': '137',
#   'death_count': '18',
#   'probable_death_count': '1',
#   'case_count_7day_avg': '1948',
#   'all_case_count_7day_avg': '2503',
#   'hosp_count_7day_avg': '139',
#   'death_count_7day_avg': '16',
#   'all_death_count_7day_avg': '17',
#   'bx_case_count': '180',
#   'bx_probable_case_count': '116',
#   'bx_hospitalized_count': '31',
#   'bx_death_count': '3',
#   'bx_probable_death_count': '0',
#   'bx_case_count_7day_avg': '327',
#   'bx_probable_case_count_7day_avg': '108',
#   'bx_all_case_count_7day_avg': '435',
#   'bx_hospitalized_count_7day_avg': '29',
#   'bx_death_count_7day_avg': '3',
#   'bx_all_death_count_7day_avg': '3',
#   'bk_case_count': '431',
#   'bk_probable_case_count': '159',
#   'bk_hospitalized_count': '41',
#   'bk_death_count': '6',
#   'bk_probable_death_count': '0',
#   'bk_case_count_7day_avg': '583',
#   'bk_probable_case_count_7day_avg': '154',
#   'bk_all_case_count_7day_avg': '737',
#   'bk_hospitalized_count_7day_avg': '43',
#   'bk_death_count_7day_avg': '5',
#   'bk_all_death_count_7day_avg': '5',
#   'mn_case_count': '252',
#   'mn_probable_case_count': '86',
#   'mn_hospitalized_count': '27',
#   'mn_death_count': '2',
#   'mn_probable_death_count': '1',
#   'mn_case_count_7day_avg': '378',
#   'mn_probable_case_count_7day_avg': '100',
#   'mn_all_case_count_7day_avg': '477',
#   'mn_hospitalized_count_7day_avg': '26',
#   'mn_death_count_7day_avg': '2',
#   'mn_all_death_count_7day_avg': '2',
#   'qn_case_count': '388',
#   'qn_probable_case_count': '159',
#   'qn_hospitalized_count': '31',
#   'qn_death_count': '7',
#   'qn_probable_death_count': '0',
#   'qn_case_count_7day_avg': '565',
#   'qn_probable_case_count_7day_avg': '165',
#   'qn_all_case_count_7day_avg': '730',
#   'qn_hospitalized_count_7day_avg': '36',
#   'qn_death_count_7day_avg': '5',
#   'qn_all_death_count_7day_avg': '5',
#   'si_case_count': '89',
#   'si_probable_case_count': '36',
#   'si_hospitalized_count': '8',
#   'si_death_count': '0',
#   'si_probable_death_count': '0',
#   'si_probable_case_count_7day_avg': '29',
#   'si_case_count_7day_avg': '95',
#   'si_all_case_count_7day_avg': '123',
#   'si_hospitalized_count_7day_avg': '7',
#   'si_death_count_7day_avg': '1',
#   'si_all_death_count_7day_avg': '1',
#   'incomplete': '0'},
#  {'date_of_interest': '2022-11-21T00:00:00.000',
#   'case_count': '3012',
#   'probable_case_count': '760',
#   'hospitalized_count': '168',
#   'death_count': '16',
#   'probable_death_count': '1',
#   'case_count_7day_avg': '1956',
#   'all_case_count_7day_avg': '2511',
#   'hosp_count_7day_avg': '139',
#   'death_count_7day_avg': '16',
#   'all_death_count_7day_avg': '17',
#   'bx_case_count': '488',
#   'bx_probable_case_count': '154',
#   'bx_hospitalized_count': '32',
#   'bx_death_count': '0',
#   'bx_probable_death_count': '1',
#   'bx_case_count_7day_avg': '320',
#   'bx_probable_case_count_7day_avg': '107',
#   'bx_all_case_count_7day_avg': '427',
#   'bx_hospitalized_count_7day_avg': '28',
#   'bx_death_count_7day_avg': '3',
#   'bx_all_death_count_7day_avg': '3',
#   'bk_case_count': '890',
#   'bk_probable_case_count': '194',
#   'bk_hospitalized_count': '43',
#   'bk_death_count': '7',
#   'bk_probable_death_count': '0',
#   'bk_case_count_7day_avg': '586',
#   'bk_probable_case_count_7day_avg': '153',
#   'bk_all_case_count_7day_avg': '739',
#   'bk_hospitalized_count_7day_avg': '44',
#   'bk_death_count_7day_avg': '5',
#   'bk_all_death_count_7day_avg': '6',
#   'mn_case_count': '605',
#   'mn_probable_case_count': '133',
#   'mn_hospitalized_count': '38',
#   'mn_death_count': '3',
#   'mn_probable_death_count': '0',
#   'mn_case_count_7day_avg': '382',
#   'mn_probable_case_count_7day_avg': '101',
#   'mn_all_case_count_7day_avg': '483',
#   'mn_hospitalized_count_7day_avg': '26',
#   'mn_death_count_7day_avg': '3',
#   'mn_all_death_count_7day_avg': '3',
#   'qn_case_count': '860',
#   'qn_probable_case_count': '240',
#   'qn_hospitalized_count': '51',
#   'qn_death_count': '6',
#   'qn_probable_death_count': '0',
#   'qn_case_count_7day_avg': '567',
#   'qn_probable_case_count_7day_avg': '166',
#   'qn_all_case_count_7day_avg': '734',
#   'qn_hospitalized_count_7day_avg': '36',
#   'qn_death_count_7day_avg': '5',
#   'qn_all_death_count_7day_avg': '5',
#   'si_case_count': '168',
#   'si_probable_case_count': '39',
#   'si_hospitalized_count': '7',
#   'si_death_count': '0',
#   'si_probable_death_count': '0',
#   'si_probable_case_count_7day_avg': '29',
#   'si_case_count_7day_avg': '99',
#   'si_all_case_count_7day_avg': '128',
#   'si_hospitalized_count_7day_avg': '7',
#   'si_death_count_7day_avg': '1',
#   'si_all_death_count_7day_avg': '1',
#   'incomplete': '0'},
#  {'date_of_interest': '2022-11-22T00:00:00.000',
#   'case_count': '2701',
#   'probable_case_count': '567',
#   'hospitalized_count': '157',
#   'death_count': '16',
#   'probable_death_count': '1',
#   'case_count_7day_avg': '2000',
#   'all_case_count_7day_avg': '2552',
#   'hosp_count_7day_avg': '140',
#   'death_count_7day_avg': '16',
#   'all_death_count_7day_avg': '17',
#   'bx_case_count': '415',
#   'bx_probable_case_count': '111',
#   'bx_hospitalized_count': '29',
#   'bx_death_count': '3',
#   'bx_probable_death_count': '0',
#   'bx_case_count_7day_avg': '323',
#   'bx_probable_case_count_7day_avg': '109',
#   'bx_all_case_count_7day_avg': '432',
#   'bx_hospitalized_count_7day_avg': '27',
#   'bx_death_count_7day_avg': '2',
#   'bx_all_death_count_7day_avg': '3',
#   'bk_case_count': '826',
#   'bk_probable_case_count': '142',
#   'bk_hospitalized_count': '36',
#   'bk_death_count': '2',
#   'bk_probable_death_count': '0',
#   'bk_case_count_7day_avg': '601',
#   'bk_probable_case_count_7day_avg': '146',
#   'bk_all_case_count_7day_avg': '747',
#   'bk_hospitalized_count_7day_avg': '43',
#   'bk_death_count_7day_avg': '5',
#   'bk_all_death_count_7day_avg': '6',
#   'mn_case_count': '540',
#   'mn_probable_case_count': '95',
#   'mn_hospitalized_count': '33',
#   'mn_death_count': '6',
#   'mn_probable_death_count': '0',
#   'mn_case_count_7day_avg': '389',
#   'mn_probable_case_count_7day_avg': '98',
#   'mn_all_case_count_7day_avg': '488',
#   'mn_hospitalized_count_7day_avg': '27',
#   'mn_death_count_7day_avg': '3',
#   'mn_all_death_count_7day_avg': '3',
#   'qn_case_count': '795',
#   'qn_probable_case_count': '183',
#   'qn_hospitalized_count': '53',
#   'qn_death_count': '3',
#   'qn_probable_death_count': '1',
#   'qn_case_count_7day_avg': '585',
#   'qn_probable_case_count_7day_avg': '169',
#   'qn_all_case_count_7day_avg': '754',
#   'qn_hospitalized_count_7day_avg': '38',
#   'qn_death_count_7day_avg': '5',
#   'qn_all_death_count_7day_avg': '5',
#   'si_case_count': '125',
#   'si_probable_case_count': '36',
#   'si_hospitalized_count': '6',
#   'si_death_count': '2',
#   'si_probable_death_count': '0',
#   'si_probable_case_count_7day_avg': '30',
#   'si_case_count_7day_avg': '102',
#   'si_all_case_count_7day_avg': '131',
#   'si_hospitalized_count_7day_avg': '7',
#   'si_death_count_7day_avg': '1',
#   'si_all_death_count_7day_avg': '1',
#   'incomplete': '0'},
#  {'date_of_interest': '2022-11-23T00:00:00.000',
#   'case_count': '2702',
#   'probable_case_count': '797',
#   'hospitalized_count': '172',
#   'death_count': '14',
#   'probable_death_count': '0',
#   'case_count_7day_avg': '2054',
#   'all_case_count_7day_avg': '2626',
#   'hosp_count_7day_avg': '143',
#   'death_count_7day_avg': '16',
#   'all_death_count_7day_avg': '16',
#   'bx_case_count': '426',
#   'bx_probable_case_count': '138',
#   'bx_hospitalized_count': '34',
#   'bx_death_count': '2',
#   'bx_probable_death_count': '0',
#   'bx_case_count_7day_avg': '324',
#   'bx_probable_case_count_7day_avg': '112',
#   'bx_all_case_count_7day_avg': '436',
#   'bx_hospitalized_count_7day_avg': '26',
#   'bx_death_count_7day_avg': '2',
#   'bx_all_death_count_7day_avg': '3',
#   'bk_case_count': '788',
#   'bk_probable_case_count': '238',
#   'bk_hospitalized_count': '49',
#   'bk_death_count': '5',
#   'bk_probable_death_count': '0',
#   'bk_case_count_7day_avg': '618',
#   'bk_probable_case_count_7day_avg': '154',
#   'bk_all_case_count_7day_avg': '772',
#   'bk_hospitalized_count_7day_avg': '43',
#   'bk_death_count_7day_avg': '5',
#   'bk_all_death_count_7day_avg': '5',
#   'mn_case_count': '561',
#   'mn_probable_case_count': '148',
#   'mn_hospitalized_count': '33',
#   'mn_death_count': '1',
#   'mn_probable_death_count': '0',
#   'mn_case_count_7day_avg': '401',
#   'mn_probable_case_count_7day_avg': '102',
#   'mn_all_case_count_7day_avg': '504',
#   'mn_hospitalized_count_7day_avg': '28',
#   'mn_death_count_7day_avg': '2',
#   'mn_all_death_count_7day_avg': '3',
#   'qn_case_count': '788',
#   'qn_probable_case_count': '243',
#   'qn_hospitalized_count': '49',
#   'qn_death_count': '3',
#   'qn_probable_death_count': '0',
#   'qn_case_count_7day_avg': '603',
#   'qn_probable_case_count_7day_avg': '175',
#   'qn_all_case_count_7day_avg': '779',
#   'qn_hospitalized_count_7day_avg': '40',
#   'qn_death_count_7day_avg': '4',
#   'qn_all_death_count_7day_avg': '5',
#   'si_case_count': '136',
#   'si_probable_case_count': '30',
#   'si_hospitalized_count': '8',
#   'si_death_count': '3',
#   'si_probable_death_count': '0',
#   'si_probable_case_count_7day_avg': '29',
#   'si_case_count_7day_avg': '107',
#   'si_all_case_count_7day_avg': '135',
#   'si_hospitalized_count_7day_avg': '7',
#   'si_death_count_7day_avg': '1',
#   'si_all_death_count_7day_avg': '1',
#   'incomplete': '0'},
#  {'date_of_interest': '2022-11-24T00:00:00.000',
#   'case_count': '1007',
#   'probable_case_count': '349',
#   'hospitalized_count': '133',
#   'death_count': '17',
#   'probable_death_count': '4',
#   'case_count_7day_avg': '1927',
#   'all_case_count_7day_avg': '2454',
#   'hosp_count_7day_avg': '140',
#   'death_count_7day_avg': '16',
#   'all_death_count_7day_avg': '17',
#   'bx_case_count': '162',
#   'bx_probable_case_count': '77',
#   'bx_hospitalized_count': '23',
#   'bx_death_count': '3',
#   'bx_probable_death_count': '0',
#   'bx_case_count_7day_avg': '303',
#   'bx_probable_case_count_7day_avg': '104',
#   'bx_all_case_count_7day_avg': '407',
#   'bx_hospitalized_count_7day_avg': '26',
#   'bx_death_count_7day_avg': '3',
#   'bx_all_death_count_7day_avg': '3',
#   'bk_case_count': '314',
#   'bk_probable_case_count': '107',
#   'bk_hospitalized_count': '38',
#   'bk_death_count': '9',
#   'bk_probable_death_count': '1',
#   'bk_case_count_7day_avg': '583',
#   'bk_probable_case_count_7day_avg': '141',
#   'bk_all_case_count_7day_avg': '724',
#   'bk_hospitalized_count_7day_avg': '40',
#   'bk_death_count_7day_avg': '6',
#   'bk_all_death_count_7day_avg': '6',
#   'mn_case_count': '183',
#   'mn_probable_case_count': '57',
#   'mn_hospitalized_count': '22',
#   'mn_death_count': '1',
#   'mn_probable_death_count': '1',
#   'mn_case_count_7day_avg': '377',
#   'mn_probable_case_count_7day_avg': '91',
#   'mn_all_case_count_7day_avg': '468',
#   'mn_hospitalized_count_7day_avg': '27',
#   'mn_death_count_7day_avg': '2',
#   'mn_all_death_count_7day_avg': '2',
#   'qn_case_count': '302',
#   'qn_probable_case_count': '93',
#   'qn_hospitalized_count': '43',
#   'qn_death_count': '4',
#   'qn_probable_death_count': '2',
#   'qn_case_count_7day_avg': '565',
#   'qn_probable_case_count_7day_avg': '163',
#   'qn_all_case_count_7day_avg': '728',
#   'qn_hospitalized_count_7day_avg': '41',
#   'qn_death_count_7day_avg': '5',
#   'qn_all_death_count_7day_avg': '5',
#   'si_case_count': '46',
#   'si_probable_case_count': '15',
#   'si_hospitalized_count': '8',
#   'si_death_count': '0',
#   'si_probable_death_count': '0',
#   'si_probable_case_count_7day_avg': '27',
#   'si_case_count_7day_avg': '99',
#   'si_all_case_count_7day_avg': '126',
#   'si_hospitalized_count_7day_avg': '7',
#   'si_death_count_7day_avg': '1',
#   'si_all_death_count_7day_avg': '1',
#   'incomplete': '0'}]
